# %%
import pandas as p

# %%
data_dir='D:\\_NILESH\\dissertation\\data\\'

# %%
data=p.read_csv(data_dir+'cme.csv')
data
# Out:
#              Date      Time Central_PA  Width Linear_Speed  \
# 0      1996/01/11  00:14:36        267     18          499
# 1      1996/01/13  22:08:30        265     16          290
# 2      1996/01/15  07:01:10        262     43          525
# 3      1996/01/22  03:11:01        105     37          267
# 4      1996/01/26  09:16:19         90     27          262
# ...           ...       ...        ...    ...          ...
# 33735  2023/03/30  06:48:05        259     87          270
# 33736  2023/03/30  07:48:05        243    224          487
# 33737  2023/03/30  21:48:06        244     40          381
# 33738  2023/03/31  09:24:20        280     39          356
# 33739  2023/03/31  14:57:20        319    221          755
#
#       2nd_order_speed_initial 2nd_order_speed_final 20R_speed    Accel  \
# 0                         571                   426         0   -64.3*
# 1                         278                   303       372     2.8*
# ...

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Read the data from the CSV file
# # data = pd.read_csv("your_data.csv")

# # Convert the Date column to a datetime format
# data["Date"] = pd.to_datetime(data["Date"])

# # Plotting the time series graph for Kinetic Energy
# plt.figure(figsize=(12, 6))
# plt.plot(data["Date"], data["Kinetic_Energy"], color="blue")

# # Customize the plot
# plt.xlabel("Date")
# plt.ylabel("Kinetic Energy")
# plt.title("Kinetic Energy over Time")

# # Show the plot
# plt.show()

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Read the data from the CSV file
# # data = pd.read_csv("your_data.csv")

# # Convert the Date column to a datetime format
# # data["Date"] = pd.to_datetime(data["Date"])

# # Filter the data for the years 1996 to 2008
# start_date = pd.to_datetime("1996-01-01")
# end_date = pd.to_datetime("2008-12-31")
# filtered_data = data[(data["Date"] >= start_date) & (data["Date"] <= end_date)]

# # Plotting the time series graph for Kinetic Energy
# plt.figure(figsize=(12, 6))
# plt.plot(filtered_data["Date"], filtered_data["Kinetic_Energy"], color="blue")

# # Customize the plot
# plt.xlabel("Date")
# plt.ylabel("Kinetic Energy")
# plt.title("Kinetic Energy over Time (1996 to 2008)")

# # Show the plot
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the CSV file
# data = pd.read_csv("your_data.csv")

# Convert the Date column to a datetime format
data["Date"] = pd.to_datetime(data["Date"])

# Clean the "Kinetic Energy" column and convert it to numeric format
data["Kinetic_Energy"] = pd.to_numeric(data["Kinetic_Energy"], errors="coerce")

# Set the Date column as the index
data.set_index("Date", inplace=True)

# Resample the data to monthly intervals and calculate the average of Kinetic Energy
monthly_avg = data["Kinetic_Energy"].resample("M").mean()

# Plotting the time series graph for average Kinetic Energy over monthly intervals
plt.figure(figsize=(12, 6))
plt.plot(monthly_avg.index, monthly_avg, color="blue")

# Customize the plot
plt.xlabel("Date")
plt.ylabel("Average Kinetic Energy")
plt.title("Average Kinetic Energy over Monthly Intervals (1996 to 2008)")

# Show the plot
plt.show()

# %%
data["Mass"] = pd.to_numeric(data["Mass"], errors="coerce")

# Resample the data to monthly intervals and calculate the average of Mass
monthly_avg_mass = data["Mass"].resample("M").mean()

# Plotting the time series graph for average Mass over monthly intervals
plt.figure(figsize=(12, 6))
plt.plot(monthly_avg_mass.index, monthly_avg_mass, color="green")

# Customize the plot
plt.xlabel("Date")
plt.ylabel("Average Mass")
plt.title("Average Mass over Monthly Intervals")

# Show the plot
plt.show()

# %%
data["Accel"] = pd.to_numeric(data["Accel"], errors="coerce")

monthly_avg_accel = data["Accel"].resample("M").mean()

# Plotting the time series graph for average Mass over monthly intervals
plt.figure(figsize=(12, 6))
plt.plot(monthly_avg_accel.index, monthly_avg_accel, color="green")

# Customize the plot
plt.xlabel("Date")
plt.ylabel("Average Accel")
plt.title("Average Accel over Monthly Intervals")

# Show the plot
plt.show()
