# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")
import logging
logging.basicConfig(level=logging.ERROR)
data_dir='D:\\_NILESH\\dissertation\\data\\'

# %%
sun_df=pd.read_csv(data_dir+'sunspots.csv')
sun_df
# Out:
#          Year  Month  Day   Time  Greenwich sunspot group  \
# 0      1975.0    1.0  1.0  0.427                  23606.0
# 1      1975.0    1.0  1.0  0.427                  23607.0
# 2      1975.0    1.0  2.0  0.533                  23606.0
# 3      1975.0    1.0  2.0  0.533                  23607.0
# 4      1975.0    1.0  2.0  0.533                  23608.0
# ...       ...    ...  ...    ...                      ...
# 90813  2023.0    7.0  4.0  0.000                      NaN
# 90814  2023.0    7.0  4.0  0.000                      NaN
# 90815  2023.0    7.0  4.0  0.000                      NaN
# 90816  2023.0    7.0  4.0  0.000                      NaN
# 90817  2023.0    7.0  4.0  0.000                      NaN
#
#        Observed umbral area  Observed whole spot area  Corrected umbral area  \
# 0                      39.0                     302.0                   25.0
# 1                      10.0                     105.0                   10.0
# ...

# %%
column_name='Magnetic group type'
print(sun_df[column_name].unique())
sun_df[column_name].value_counts().unique
# Out:
# [nan 'A  ' 'B  ' '   ' 'BG ' 'BGD' 'BD ' 'GD ' 'G  ' 'B-D' ' BG' 'Gam']
# <bound method Series.unique of B      39810
# A      25211
# BG      4235
# BGD     1628
# BD       536
#          158
# GD        35
# G         16
#  BG        4
# B-D        1
# Gam        1
# Name: Magnetic group type, dtype: int64>

# %%
len(sun_df)
# Out:
# 90818

# %%
df=sun_df
nan_count = df[column_name].isna().sum()
nan_count = df[column_name].isnull().sum()
print("Number of NaN values in the column:", nan_count)
# Out:
# Number of NaN values in the column: 19183
